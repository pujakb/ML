# %%
import pandas as pd
from sklearn.cluster import KMeans
import collections
import matplotlib.pyplot as plt
from matplotlib import colors
import pylab as pl
# %matplotlib inline

# %%
df = pd.read_csv (r'C:\Users\Wine.csv')
print(df)
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# 5      14.20        1.76  2.45          15.2        112           3.27
# 6      14.39        1.87  2.45          14.6         96           2.50
# 7      14.06        2.15  2.61          17.6        121           2.60
# 8      14.83        1.64  2.17          14.0         97           2.80
# 9      13.86        1.35  2.27          16.0         98           2.98
# 10     14.10        2.16  2.30          18.0        105           2.95
# 11     14.12        1.48  2.32          16.8         95           2.20
# ...

# %%
df.head(2)
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
#
#    OD280  Proline  Customer_Segment
# 0   3.92     1065                 1
# 1   3.40     1050                 1

# %%
df.tail(2)
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 176        0.68                  0.53             1.46              9.3  0.60
# 177        0.76                  0.56             1.35              9.2  0.61
#
#      OD280  Proline  Customer_Segment
# 176   1.62      840                 3
# 177   1.60      560                 3

# %%
del df['Customer_Segment']

# %%
df.tail(2)
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 176        0.68                  0.53             1.46              9.3  0.60
# 177        0.76                  0.56             1.35              9.2  0.61
#
#      OD280  Proline
# 176   1.62      840
# 177   1.60      560

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# 5      14.20        1.76  2.45          15.2        112           3.27
# 6      14.39        1.87  2.45          14.6         96           2.50
# 7      14.06        2.15  2.61          17.6        121           2.60
# 8      14.83        1.64  2.17          14.0         97           2.80
# 9      13.86        1.35  2.27          16.0         98           2.98
# 10     14.10        2.16  2.30          18.0        105           2.95
# 11     14.12        1.48  2.32          16.8         95           2.20
# ...

# %%
df[:10]
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
# 5    14.20        1.76  2.45          15.2        112           3.27
# 6    14.39        1.87  2.45          14.6         96           2.50
# 7    14.06        2.15  2.61          17.6        121           2.60
# 8    14.83        1.64  2.17          14.0         97           2.80
# 9    13.86        1.35  2.27          16.0         98           2.98
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
# Alcohol                 178 non-null float64
# Malic_Acid              178 non-null float64
# Ash                     178 non-null float64
# Ash_Alcanity            178 non-null float64
# Magnesium               178 non-null int64
# Total_Phenols           178 non-null float64
# Flavanoids              178 non-null float64
# Nonflavanoid_Phenols    178 non-null float64
# Proanthocyanins         178 non-null float64
# Color_Intensity         178 non-null float64
# Hue                     178 non-null float64
# OD280                   178 non-null float64
# Proline                 178 non-null int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
df['Alcohol'].sum()
# Out:
# 2314.11

# %%
df['Alcohol'].count()
# Out:
# 178

# %%
df['Alcohol'].max()
# Out:
# 14.83

# %%
df.corr()
# Out:
#                        Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  \
# Alcohol               1.000000    0.094397  0.211545     -0.310235   0.270798
# Malic_Acid            0.094397    1.000000  0.164045      0.288500  -0.054575
# Ash                   0.211545    0.164045  1.000000      0.443367   0.286587
# Ash_Alcanity         -0.310235    0.288500  0.443367      1.000000  -0.083333
# Magnesium             0.270798   -0.054575  0.286587     -0.083333   1.000000
# Total_Phenols         0.289101   -0.335167  0.128980     -0.321113   0.214401
# Flavanoids            0.236815   -0.411007  0.115077     -0.351370   0.195784
# Nonflavanoid_Phenols -0.155929    0.292977  0.186230      0.361922  -0.256294
# Proanthocyanins       0.136698   -0.220746  0.009652     -0.197327   0.236441
# Color_Intensity       0.546364    0.248985  0.258887      0.018732   0.199950
# Hue                  -0.071747   -0.561296 -0.074667     -0.273955   0.055398
# ...

# %%
df.cov()
# Out:
#                          Alcohol  Malic_Acid        Ash  Ash_Alcanity  \
# Alcohol                 0.659062    0.085611   0.047115     -0.841093
# Malic_Acid              0.085611    1.248015   0.050277      1.076332
# Ash                     0.047115    0.050277   0.075265      0.406208
# Ash_Alcanity           -0.841093    1.076332   0.406208     11.152686
# Magnesium               3.139878   -0.870780   1.122937     -3.974760
# Total_Phenols           0.146887   -0.234338   0.022146     -0.671149
# Flavanoids              0.192033   -0.458630   0.031535     -1.172083
# Nonflavanoid_Phenols   -0.015754    0.040733   0.006358      0.150422
# Proanthocyanins         0.063518   -0.141147   0.001516     -0.377176
# Color_Intensity         1.028283    0.644838   0.164654      0.145024
# Hue                    -0.013313   -0.143326  -0.004682     -0.209118
# OD280                   0.041698   -0.292447   0.000762     -0.656234
# ...

# %%
df.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
wineNorm <- as.data.frame(scale(Wine))
# Out:
#   File "<ipython-input-61-2363dd295393>", line 1
#     wineNorm <- as.data.frame(scale(Wine))
#                  ^
# SyntaxError: invalid syntax

# %%
df_norm = (df - df.mean()) / (df.max() - df.min())
df_norm
# Out:
#       Alcohol  Malic_Acid       Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    0.323522   -0.123784  0.033948     -0.200770   0.296287       0.174099
# 1    0.052469   -0.109950 -0.121132     -0.427574   0.002809       0.122375
# 2    0.041943    0.004674  0.162290     -0.046131   0.013679       0.174099
# 3    0.360364   -0.076353  0.071381     -0.138915   0.144113       0.536168
# 4    0.062995    0.050129  0.269242      0.077580   0.198461       0.174099
# 5    0.315627   -0.113903  0.044643     -0.221389   0.133244       0.336168
# 6    0.365627   -0.092164  0.044643     -0.252317  -0.040669       0.070651
# 7    0.278785   -0.036828  0.130205     -0.097678   0.231070       0.105134
# 8    0.481416   -0.137618 -0.105089     -0.283245  -0.029800       0.174099
# 9    0.226153   -0.194930 -0.051613     -0.180152  -0.018930       0.236168
# 10   0.289311   -0.034851 -0.035571     -0.077059   0.057157       0.225823
# ...

# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
df=df[0:10]
df
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
# 5    14.20        1.76  2.45          15.2        112           3.27
# 6    14.39        1.87  2.45          14.6         96           2.50
# 7    14.06        2.15  2.61          17.6        121           2.60
# 8    14.83        1.64  2.17          14.0         97           2.80
# 9    13.86        1.35  2.27          16.0         98           2.98
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# ...

# %%
def correlation_matrix(df):
    from matplotlib import pyplot as plt
    from matplotlib import cm as cm

    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 30)
    cax = ax1.imshow(df.corr(), interpolation="nearest", cmap=cmap)
    ax1.grid(True)
    plt.title('Relation between different attribute')
    labels=['Alcohol','Ash','Ash_alkanity','Color_intensity','Flavonoids','Hue','Magnesium','Mallic_Acid','Nonflavonoid_phenols','OD280','Proanthocyanins','Proline','Total_Phenols',]
    ax1.set_xticklabels(labels,fontsize=6)
    ax1.set_yticklabels(labels,fontsize=6)
    # Add colorbar, make sure to specify tick locations to match desired ticklabels
    fig.colorbar(cax, ticks=[.75,.8,.85,.90,.95,1])
    plt.show()

correlation_matrix(df)
